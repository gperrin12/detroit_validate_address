# %% [markdown]
# ## Project 5 - Rental Statuses
# - created 7-10-22 by GTP
# - https://docs.google.com/document/d/1LIJTlCsx54zIG5sOX3heSj00YqdzhZ9c/edit
# - this notebook specifically focuses on rental status dataset:
# ### Goals:
# 1. geocode missing lat/lons for rental statuses
# 2. rental status table, but with building ids attached (address id is nice to have)
# - *Description*: BSEED has entered a lot of data into free text fields within Accela. Would be useful to find ways to scrape and organize this data so it is useable. Unit data and Certificates of Occupancy are some of our biggest gaps. This might be a way to use administrative data to version and validate 2020 data.
# - Technical Skill Level: Medium-High. Skilled at applying Regex to text strings using SQL and/or Python. Experience working with geospatial data, in ArcGIS or otherwise.
# - Scope: There are 595 records in the Certificates of Occupancy dataset and 5,930 records in the Certificates of Compliance dataset. Depending on skill level, this could take 6-8 weeks.
# - Inputs: Certificates of Compliance, Certificates of Occupancy, Rental Registration data
# - General Process:
# - Use GIS or Base Units Explorer tool to link Certificates of Occupancy to specific building ids, to create timestamps for when a building was ready for occupants.
# - Geocode the addresses in the Certificate of Compliance and Rental Registration datasets and note any addresses that can’t be matched through a manual rematching process and may be missing altogether from the database.

# %%
#import data libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import numbers
import decimal
#import data science packages
import scipy
import scipy.stats as stats

np.random.seed(222)
# %matplotlib inline
pd.option_context('display.max_columns',999)

# %%
#import geographic analysis libraries
import geopandas as gpd
from geopandas import GeoDataFrame
import shapely as shp
from shapely.geometry import Point
from shapely.geometry import shape
import os
import re
from fiona.crs import from_epsg
import pysal as ps
import re
from googlemaps import Client as GoogleMaps
import googlemaps
import gmaps
# Out:
# /Users/geoffperrin/miniconda3/lib/python3.8/site-packages/pysal/explore/segregation/network/network.py:15: UserWarning: You need pandana and urbanaccess to work with segregation's network module
# You can install them with  `pip install urbanaccess pandana` or `conda install -c udst pandana urbanaccess`
#   warn(
# /Users/geoffperrin/miniconda3/lib/python3.8/site-packages/pysal/model/spvcm/abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %%
# This is where we will need the API key
gmaps = googlemaps.Client(key=os.environ['GOOGLE_GEOCODER_API'])

# %%
#set crs for entire analysis
crs = {'init': 'epsg:4326'}

# %% [markdown]
# ### data sources
#
# Rental Registrations: https://data.detroitmi.gov/datasets/rental-statuses-1/explore
# - (6-1-22): I'll address this next week with Alice on our next call
#
# Base Units: https://base-units-detroitmi.hub.arcgis.com/datasets/detroitmi::units-1/about
# - jimmy mcbroom put this together
#
# https://cityofdetroit.github.io/base-unit-tools/explorer

# %% [markdown]
# ## Rental Statuses / Rental Registrations
# ### Notes:
# - https://data.detroitmi.gov/datasets/rental-statuses-1/explore
# - no descriptions / free text, so could be a limitation on using that to geocode
# - BSEED data overly relies on parcels, so they can't really take into account buildings that have both rentals _and_ owner occupied units, like 120 seward
# - so, those mixed buildings will not all be in this data, and the counts will be low. 120 seward only has 2 observations
# - bseed probably only cares about building level data i.e. is the building sound and safe
# - bseed is city department (https://detroitmi.gov/departments/buildings-safety-engineering-and-environmental-department)

# %% [markdown]
# ## Questions for Alice (7-10-22):
# 1. 1. What is the relationship between unit_id and occupancy_gdf? Addr_id is null for everything
# 2. What is the city’s geocoder?

# %%
rental_gdf = gpd.read_file('../data/Rental_Statuses/Rental_Statuses.shp')

# %%
len(rental_gdf[rental_gdf['geometry'].isna()])/len(rental_gdf)
# Out:
# 0.00803870216790339

# %%
len(rental_gdf[rental_gdf['geometry'].isna()])
# Out:
# 221

# %%
rental_gdf_nogeocode = rental_gdf[rental_gdf['geometry'].isna()]

# %%
len(rental_gdf_nogeocode)
# Out:
# 221

# %%
rental_gdf_nogeocode['address_for_geocode'] = rental_gdf_nogeocode['street_num'].astype(str) + ' ' +\
                                                  rental_gdf_nogeocode['street_dir'].astype(str) + ' ' +\
                                                  rental_gdf_nogeocode['street_nam'].astype(str) + ' ' +\
                                                  rental_gdf_nogeocode['street_typ'].astype(str) + ' ' +\
                                                  'DETROIT MI'
# Out:
# /Users/geoffperrin/miniconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
rental_gdf_nogeocode['address_for_geocode'] = rental_gdf_nogeocode['address_for_geocode'].str.replace(r'None', '')
# Out:
# /Users/geoffperrin/miniconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
rental_gdf_nogeocode.sample(5)
# Out:
#             record_id street_num street_dir                street_nam  \
# 27480  RNTR2021-00097       5091       None  -93 E OUTER DRIVE BLDG D
# 130     REG2020-00785       1503       None                    LARNED
# 22375   REG2022-04536    13910.0       None                SOUTHFIELD
# 12263   REG2021-04320     1505.0       None                    LARNED
# 17282   REG2021-10829    15452.0       None                SOUTHFIELD
#
#       street_typ  date_statu      zip                            record_typ  \
# 27480       None  2021-05-05    48234  Rental Property Registration Renewal
# 130         None  2020-02-01    48207                   Rental Registration
# 22375       None  2022-03-31  48227.0                   Rental Registration
# 12263       None  2021-05-21  48207.0                   Rental Registration
# 17282       None  2021-12-01  48227.0                   Rental Registration
#
#                            owner_name                    owner_addr  ...  \
# 27480    INTERNATIONAL APARTMENTS LLC            32500 W EIGHT MILE  ...
# 130                ORLEANS OWNERS LLC                 1531 E LARNED  ...
# 22375    NORTH WEST INVESTMENTS 3 LLC          21348 Telegraph Road  ...
# 12263               ORLEANS OWNER LLC   2550 TELEGRAPH RD SUITE 200  ...
# 17282  FORECLOSURE CAPITAL OF AMERICA  1801 CENTURY PARK E STE 2400  ...
#
#        status parcel_id lon lat ObjectId geometry  \
# 27480  Issued      None NaN NaN    27481     None
# 130    Issued      None NaN NaN      131     None
# 22375  Issued      None NaN NaN    22376     None
# 12263  Issued      None NaN NaN    12264     None
# 17282  Issued      None NaN NaN    17283     None
#
#                               address_for_geocode                    lat_lon  \
# 27480  5091  -93 E OUTER DRIVE BLDG D  DETROIT MI   (42.331427, -83.0457538)
# 130                      1503  LARNED  DETROIT MI  (42.3384166, -83.0243986)
# 22375             13910.0  SOUTHFIELD  DETROIT MI  (42.3521947, -83.2159785)
# 12263                  1505.0  LARNED  DETROIT MI  (42.3384166, -83.0243986)
# 17282             15452.0  SOUTHFIELD  DETROIT MI  (42.3521947, -83.2159785)
#
#          new_lat    new_lon
# 27480  42.331427 -83.045754
# 130    42.338417 -83.024399
# 22375  42.352195 -83.215979
# 12263  42.338417 -83.024399
# 17282  42.352195 -83.215979
#
# [5 rows x 24 columns]

# %%
def google_geocode(address_to_geocode):
    geocode_result = gmaps.geocode(address_to_geocode)
    lat = geocode_result[0]['geometry']['location']['lat']
    lon = geocode_result[0]['geometry']['location']['lng']
    return lat, lon

# %%
def return_lat(lat_lon):
    return lat_lon[0]

def return_lon(lat_lon):
    return lat_lon[1]

# %%
rental_gdf_nogeocode['lat_lon'] = rental_gdf_nogeocode['address_for_geocode'].apply(lambda x: google_geocode(x))
# Out:
# /Users/geoffperrin/miniconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
rental_gdf_nogeocode['new_lat'] = rental_gdf_nogeocode['lat_lon'].apply(return_lat)
rental_gdf_nogeocode['new_lon'] = rental_gdf_nogeocode['lat_lon'].apply(return_lon)

# %%
rental_gdf_nogeocode.to_csv('../data/exports/rental_gdf_nogeocode_geocoded.csv')

# %% [markdown]
# ## Match building ids to record_ids - rental_gdf_nogeocode (address id is nice to have)
# - Process for looking up building IDs in rental df:
# 1. Manually look up (with zoom / etc) on the https://cityofdetroit.github.io/base-unit-tools/explorer
# 2. If I can find something close, great!
# 3. If not, look up owner_name in rental_df in the parcel_df (i.e. parcel_gdf[(parcel_gdf['taxpayer_1'].str.contains(<name to look up>))]
# 4. If able to find building_id, add to https://docs.google.com/spreadsheets/d/1DVmnUbSJ4FDOLdcrCOZX5To_WMc1nk9agYTxK5jyFBU/edit#gid=0
# 5. If unable, add to notes column noting that

# %% [markdown]
# ### base units table
# - source: https://base-units-detroitmi.hub.arcgis.com/

# %% [markdown]
# - for 18224 hartwell, could be a typo (google maps shows a point right at the lodge and hartwell, without an address there) - we _could_ look donna coulter up in the assessor's db (parcel dataset on open data portal) to see if the address is correct there

# %% [markdown]
# ### example for RNTR2021-00099 / 5061 E outer drive bldg F
# - 17016320.003 is parcel ID
# - dashes (like -67 E outer drive) trips up the geocoder
# - we manually looked this up on https://cityofdetroit.github.io/base-unit-tools

# %% [markdown]
# ### example for REG2021-06367 / 5010 OPAL
# - 21078528. is parcel ID
# - looking up in base units explorer, it has it as 5010 canyon - bseed thought this was opal (on the corner of opal and canyon) - could be that the assessor thought it was on opal
# - we can report this to the assessor's to fix this

# %% [markdown]
# ## Parcel Data
# - https://data.detroitmi.gov/datasets/parcels-2/explore?location=42.352680%2C-83.099134%2C10.81
# - fuzzy match on Donna Coulter

# %%
parcel_gdf = gpd.read_file('../data/Parcels/Parcels.shp')

# %%
parcel_gdf_nona = parcel_gdf[~parcel_gdf['taxpayer_1'].isna()]

# %%
parcel_gdf_nona[(parcel_gdf_nona['taxpayer_1'].str.contains('MARTINA'))]
# Out:
#         OBJECTID  object_id    parcel_num ward              address  \
# 432          433       3514     16013207.   16        4013 JUNCTION
# 493          494       3576    16001715-6   16    5656 MICHIGAN AVE
# 5207        5208       7902    18002344-5   18    7123 MICHIGAN AVE
# 5242        5243       7937     18002343.   18    7111 MICHIGAN AVE
# 5270        5271       7964     18002342.   18    7109 MICHIGAN AVE
# 5318        5319       9610     18008974.   18           2364 GREEN
# 9401        9402      13293     20007311.   20          2385 INGLIS
# 9951        9952      13842     18009780.   18         4632 CENTRAL
# 10833      10834      13117     20007304.   20          2431 INGLIS
# 11046      11047      12548     20004192.   20        7743 W VERNOR
# 11068      11069      12570     20004191.   20        7731 W VERNOR
# 12351      12352      14235     18011849.   18         4415 52ND ST
# 15053      15054      17351     20009954.   20       8017 RADCLIFFE
# 15827      15828      18924     20006142.   20        2550 LAWNDALE
# 36700      36701      38192     16020297.   16     19484 SANTA ROSA
# 46473      46474      49564     18016514.   18           8256 FREDA
# 62731      62732      64601     22028290.   22        15019 SNOWDEN
# 62732      62733      64602     22028291.   22        15009 SNOWDEN
# 102204    102205     104885     22084080.   22        6151 STAHELIN
# 116430    116431     119088     22083278.   22       18484 STAHELIN
# 139047    139048     141277    22119714-6   22    8157 WEST PARKWAY
# 139318    139319     141547     22116727.   22         7312 CHATHAM
# 151135    151136     152614    22001516-8   22        22606 TIREMAN
# 173041    173042     174913  07001957.050   07      1919 ORLEANS 50
# 189143    189144     191802     13022488.   13         19392 REVERE
# 201451    201452     205330     13016754.   13         19171 CONLEY
# 201452    201453     205331     13016755.   13         19165 CONLEY
# 201453    201454     205332     13016756.   13         19159 CONLEY
# 238809    238810     241102     12010854.   12        16503 LINWOOD
# 262357    262358     265439     21024827.   21  14788 ROSSINI DRIVE
# 267748    267749     271226     21015046.   21       14255 MAYFIELD
# 268085    268086     271564     21015047.   21       14259 MAYFIELD
# 272544    272545     275225     21008208.   21        13031 CHELSEA
# 272653    272654     275334     21008209.   21        13039 CHELSEA
# 274486    274487     277969     21015054.   21       14425 MAYFIELD
# 279377    279378     282077     21053519.   21         411 EASTLAWN
# 296159    296160     298395     21027284.   21     16495 COLLINGHAM
# 322166    322167     325223     14003007.   14         4065 PINGREE
# 331948    331949     335027     16009750.   16         2106 LANSING
# 333505    333506     336595     16001388.   16          4840 KONKEL
# 345948    345949     348204    12009030-0   12         2001 24TH ST
# 357115    357116     358599     20010807.   20         4417 WESTERN
# 361369    361370     364063     16009622.   16       1133 MCKINSTRY
#
#        council_di zip_code                           taxpayer_1 taxpayer_2  \
# 432             6    48210  SANCHEZ, MARTINA, TORRES, YOLANDA &       None
# 493             6    48210            SANROMAN, JAMIE & MARTINA       None
# 5207            6    48210                      MEDINA, MARTINA       None
# 5242            6    48210                      MEDINA, MARTINA       None
# 5270            6    48210                      MEDINA, MARTINA       None
# 5318            6    48209        MEDINA, FRANCISCO A & MARTINA       None
# 9401            6    48209    HERNANDEZ, JOSE & GARCIA, MARTINA       None
# 9951            6    48210                      MEDINA, MARTINA       None
# 10833           6    48209        MEDINA, FRANCISCO A & MARTINA       None
# 11046           6    48209            SANROMAN, JAMIE & MARTINA       None
# 11068           6    48209            SANROMAN, JAMIE & MARTINA       None
# 12351           6    48210        NINO, MARTINA & RODRIQUEZ, S.       None
# 15053           6    48210         PEREZ,SAUL & ZEPEDA, MARTINA       None
# 15827           6    48209              DURAN--MIRANDA, MARTINA       None
# 36700           2    48221                     EVANS, MARTINA L       None
# 46473           7    48204                   CURTIS, MARTINA L.       None
# 62731           2    48227                       LOUIS, MARTINA       None
# 62732           2    48227                       LOUIS, MARTINA       None
# 102204          7    48228             DUDLEY, MARTINA SINCLAIR       None
# 116430          1    48219       WILLIAMS, DEANDRE C. & MARTINA       None
# 139047          7    48239                       ALLEN, MARTINA       None
# 139318          7    48239          SANTOS, HERNANDEZ & MARTINA       None
# 151135          7    48239                        BUDD, MARTINA       None
# 173041          5     None              HOLT, CLAYBON & MARTINA       None
# 189143          3    48234    HARRIS, MARTINA & RAHEEM (MINORS)       None
# 201451          3    48234                        KING, MARTINA       None
# 201452          3    48234                        KING, MARTINA       None
# 201453          3    48234                        KING, MARTINA       None
# 238809          2    48221                      MARTINA, MARTIN       None
# 262357          3    48205                        REID, MARTINA       None
# 267748          4    48205      RICHARDSON, RAYMOND K & MARTINA       None
# 268085          4    48205      RICHARDSON, RAYMOND K & MARTINA       None
# 272544          4    48213                     MATLOCK, MARTINA       None
# 272653          4    48213                     MATLOCK, MARTINA       None
# 274486          4    48205        RICHARDSON, RAYMOND & MARTINA       None
# 279377          4    48215            MARTINA, DAVID & MICHELLE       None
# 296159          3    48205                     STEEN, MARTINA B       None
# 322166          5    48204                BEATO, BELKIS MARTINA       None
# 331948          6    48209              CALZADA, SANDRA MARTINA       None
# 333505          6    48210               DURAN-MIRANDA, MARTINA       None
# 345948          6    48216                      GUZMAN, MARTINA       None
# 357115          6    48210    MARTINAZ, JUAN & KASPER, ZULEMA D       None
# 361369          6    48209  DOMINGUEZ, CARLOS & BLANCO, MARTINA       None
#
#                  taxpayer_s  ... assessed_v taxable_va landmap        related  \
# 432           4013 JUNCTION  ...    12500.0     5339.0     104           None
# 493         32763 BONDIE DR  ...   103000.0    16657.0     104           None
# 5207      7111 MICHIGAN AVE  ...     3900.0     3900.0     112           None
# 5242      7111 MICHIGAN AVE  ...    34200.0    16671.0     112           None
# 5270     7109 MICHIGAN AVE.  ...    13300.0     4967.0     112           None
# 5318             2394 GREEN  ...    23700.0    14690.0     115           None
# 9401         2385 INGLIS ST  ...    13400.0     6756.0     124           None
# 9951           4632 CENTRAL  ...        0.0        0.0     126           None
# 10833       2392 N GREEN ST  ...    11800.0     7406.0     124           None
# 11046       32762 BONDIE DR  ...    85600.0    31609.0     124           None
# 11068       32762 BONDIE DR  ...     4300.0     3853.0     124           None
# 12351          4415 52ND ST  ...    11300.0     8886.0     126           None
# 15053     8017 RADCLIFFE ST  ...    12400.0    10435.0     130           None
# 15827          2550 LAWDALE  ...    14600.0    10332.0     135           None
# 36700   19484 SANTA ROSA DR  ...    19400.0    13286.0     170           None
# 46473         8256 FREDA ST  ...    23300.0    15870.0     185           None
# 62731      15019 SNOWDEN ST  ...    14600.0     8609.0     204           None
# 62732         15019 SNOWDEN  ...      400.0      324.0     204           None
# 102204        6151 STAHELIN  ...    12600.0     9627.0     267           None
# 116430       18484 STAHELIN  ...    17800.0    11214.0     280           None
# 139047    8157 WEST PARKWAY  ...    25700.0    17219.0     329           None
# 139318         7312 CHATHAM  ...    13000.0     8748.0     328           None
# 151135        22606 TIREMAN  ...    29500.0    20091.0     329           None
# 173041         1919 ORLEANS  ...    26200.0     2833.0     391           None
# 189143      19392 REVERE ST  ...    11600.0     5940.0     409           None
# 201451         19165 CONLEY  ...      300.0      300.0     429           None
# 201452      19165 CONLEY ST  ...    16000.0     5666.0     429           None
# 201453         19165 CONLEY  ...      300.0      300.0     429           None
# 238809       15400 OAKFIELD  ...    32700.0    13405.0     050           None
# 262357        14788 ROSSINI  ...    18900.0    18900.0     542           None
# 267748       14281 MAYFIELD  ...      200.0      200.0     538           None
# 268085       14281 MAYFIELD  ...      200.0      200.0     538           None
# 272544        13031 CHELSEA  ...    12400.0     9944.0     547           None
# 272653        13039 CHELSEA  ...        0.0        0.0     547           None
# 274486       14281 MAYFIELD  ...      200.0      200.0     545           None
# 279377         411 EASTLAWN  ...     1400.0     1400.0     554      27190019.
# 296159     16495 COLLINGHAM  ...    16400.0    11449.0     569           None
# 322166   7101 RIVER GLEN DR  ...     6100.0     6100.0     079           None
# 331948         2106 LANSING  ...    13300.0     8748.0     095           None
# 333505          4840 KONKEL  ...    11500.0     7299.0     093           None
# 345948         2001 24TH ST  ...    31500.0    20937.0     073  23002004.0024
# 357115      4295 WESTERN ST  ...    10600.0     8040.0     132           None
# 361369    1133 MCKINSTRY ST  ...    20000.0     7629.0     096           None
#
#        zoning subdivisio                                         legal_desc  \
# 432        R2       None  W JUNCTION 35 BLK E-BRUSHS SUB L16 P24 PLATS, ...
# 493        B3       None  N MICHIGAN 11 & 12 BLK B-BRUSHS SUB L16 P24 PL...
# 5207       B4       None  S MICHIGAN 143&142 EXC MICHIGAN AVE AS WD C A ...
# 5242       B4       None  S MICHIGAN 144 EXC MICHIGAN AVE AS WD C A & J ...
# 5270       B4       None  S MICHIGAN 145 EXC MICHIGAN AVE AS WD C A & J ...
# 5318       R2       None  E GREEN 57 RIEDENS SUB L29 P77 PLATS, W C R 18...
# 9401       R2       None  W INGLIS 136 GRANTORS SUB L14 P27 PLATS, W C R...
# 9951       R2       None  PROPERTY EXEMPT FROM AD VALOREM TAXES AND ASSE...
# 10833      R2       None  W INGLIS 129 GRANTORS SUB L14 P27 PLATS, W C R...
# 11046      B4       None  S VERNOR HIGHWAY 50&51 FERNDALE AVE SUB L30 P5...
# 11068      B4       None  S VERNOR HIGHWAY 48&49 FERNDALE AVE SUB L30 P5...
# 12351      R2       None  W 52ND 72 CONRAD CLIPPERTS SUB NO 2 L28 P33 PL...
# 15053      R2       None  S RADCLIFFE 1353 SMART FARM SUB L34 P32-3 PLAT...
# 15827      R2       None  E LAWNDALE 208 HARRAHS TOLEDO AVE SUB L16 P11 ...
# 36700      R1       None  E SANTA ROSA DR 231 AND W 9 FT OF VAC ALLEY AD...
# 46473      R1       None  E FREDA 2113 ROBERT OAKMAN LAND COS AVIATION F...
# 62731      R1       None  W SNOWDEN 68 ALCOMA SUB L34 P85 PLATS, WCR 22/...
# 62732      R1       None  W SNOWDEN 67 ALCOMA SUB L34 P85 PLATS, WCR 22/...
# 102204     R1       None  W STAHELIN 29 AND E 9 FT OF VAC ALLEY ADJ HITC...
# 116430     R1       None  Property exempt from Ad Valorem taxes and asse...
# 139047     R1       None  W-WEST PARKWAY 740&741 N 10 FT 742 AND E 10 FT...
# 139318     R1       None  E CHATHAM 319 AND W 9 FT OF VAC ALLEY ADJ FRIS...
# 151135     R1       None  N TIREMAN E 15 FT 1259 1258&1257 AND S 10 FT V...
# 173041     R6       None  W ORLEANS BLDG 4 CONDO 50 WAYNE COUNTY CONDOMI...
# 189143     R1       None  E REVERE 396 BIRCH LAWN L45 P98 PLATS, W C R 1...
# 201451     R1       None  PROPERTY EXEMPT FROM AD VALOREM TAXES AND ASSE...
# 201452     R1       None  W CONLEY 40 SEYMOUR & TROESTERS POLONIA PK L46...
# 201453     R1       None  W CONLEY 39 SEYMOUR & TROESTERS POLONIA PK L46...
# 238809     R1       None  W LINWOOD 277 MARTIN PARK SUB L32 P44 PLATS, W...
# 262357     R1       None  S ROSSINI DR 73 ED DE GRANDCHAMP GRATIOT FARM ...
# 267748     R2       None  N MAYFIELD AVE E 6 FT 35 W 25 FT 34 STEPHEN YO...
# 268085     R2       None  N MAYFIELD AVE E 12 FT 34 W 19 FT 33 STEPHEN Y...
# 272544     R2       None  N CHELSEA E 10 FT 72 71 AND S 10 FT VAC ALLEY ...
# 272653     R2       None  N CHELSEA 70 & S 10 FT OF VAC ALLEY ADJ CHELSE...
# 274486     R2       None  Property exempt from Ad Valorem taxes and asse...
# 279377     R2       None  W EASTLAWN 183 RIVERSIDE BLVD SUB L37 P93 PLAT...
# 296159     R1       None  N COLLINGHAM DR 138 EXC W 21.25 FT 139 EXC E 1...
# 322166     R2       None  Property exempt from Ad Valorem taxes and asse...
# 331948     R2       None  E LANSING 24 J MOTT WILLIAMS SUB L18 P68 PLATS...
# 333505     R2       None  N KONKEL 104 MC MILLAN & WHITINGS SUB L14 P98 ...
# 345948     R3     L8 P58  W 24TH S 12.75 FT 35, 50 WILLIAM E LOVETTS SUB...
# 357115     R2       None  W WESTERN 7&8 NALLS SUB L14 P75 PLATS, WCR 20/...
# 361369     R2       None  W MCKINSTRY 40 J C D WILLIAMS SUB L4 P20 PLATS...
#
#        SHAPE_Leng    SHAPE_Area  \
# 432      0.000878  3.045535e-08
# 493      0.000919  5.081433e-08
# 5207     0.000657  2.669341e-08
# 5242     0.000511  1.345893e-08
# 5270     0.000511  1.345920e-08
# 5318     0.001038  3.743559e-08
# 9401     0.000878  3.039149e-08
# 9951     0.000952  3.372137e-08
# 10833    0.000878  3.039157e-08
# 11046    0.000881  4.077866e-08
# 11068    0.000878  4.045764e-08
# 12351    0.001013  3.608150e-08
# 15053    0.000865  3.333390e-08
# 15827    0.000878  3.059088e-08
# 36700    0.001108  4.876700e-08
# 46473    0.001108  4.881759e-08
# 62731    0.000990  3.858818e-08
# 62732    0.000991  3.822453e-08
# 102204   0.001204  5.404047e-08
# 116430   0.001065  4.658861e-08
# 139047   0.001087  5.574679e-08
# 139318   0.001212  5.438762e-08
# 151135   0.001041  6.559679e-08
# 173041   0.003146  2.591508e-08
# 189143   0.000905  3.040166e-08
# 201451   0.001190  4.797379e-08
# 201452   0.001187  4.783295e-08
# 201453   0.001187  4.757047e-08
# 238809   0.001126  6.159330e-08
# 262357   0.000985  4.695609e-08
# 267748   0.000839  3.490109e-08
# 268085   0.000839  3.500973e-08
# 272544   0.001111  5.698894e-08
# 272653   0.001039  4.287383e-08
# 274486   0.000872  3.965062e-08
# 279377   0.001084  4.850488e-08
# 296159   0.001033  5.451258e-08
# 322166   0.000860  3.667795e-08
# 331948   0.001162  4.251200e-08
# 333505   0.000957  3.827552e-08
# 345948   0.001486  8.038811e-08
# 357115   0.001234  7.620738e-08
# 361369   0.001161  4.261291e-08
#
#                                                  geometry
# 432     POLYGON ((-83.11346 42.33280, -83.11314 42.332...
# 493     POLYGON ((-83.11280 42.33160, -83.11262 42.331...
# 5207    POLYGON ((-83.13236 42.33097, -83.13221 42.330...
# 5242    POLYGON ((-83.13221 42.33097, -83.13214 42.330...
# 5270    POLYGON ((-83.13214 42.33097, -83.13206 42.330...
# 5318    POLYGON ((-83.12166 42.31489, -83.12165 42.314...
# 9401    POLYGON ((-83.12966 42.31195, -83.12965 42.311...
# 9951    POLYGON ((-83.13648 42.32964, -83.13612 42.329...
# 10833   POLYGON ((-83.13003 42.31246, -83.13002 42.312...
# 11046   POLYGON ((-83.12505 42.31222, -83.12492 42.312...
# 11068   POLYGON ((-83.12492 42.31228, -83.12479 42.312...
# 12351   POLYGON ((-83.13518 42.32862, -83.13518 42.328...
# 15053   POLYGON ((-83.14796 42.34016, -83.14787 42.340...
# 15827   POLYGON ((-83.13453 42.31185, -83.13421 42.311...
# 36700   POLYGON ((-83.14371 42.43659, -83.14371 42.436...
# 46473   POLYGON ((-83.15984 42.35501, -83.15940 42.355...
# 62731   POLYGON ((-83.17738 42.40030, -83.17738 42.400...
# 62732   POLYGON ((-83.17738 42.40021, -83.17737 42.400...
# 102204  POLYGON ((-83.22459 42.33414, -83.22459 42.334...
# 116430  POLYGON ((-83.22733 42.42608, -83.22732 42.426...
# 139047  POLYGON ((-83.26500 42.35124, -83.26500 42.351...
# 139318  POLYGON ((-83.25983 42.34345, -83.25982 42.343...
# 151135  POLYGON ((-83.26210 42.34947, -83.26189 42.349...
# 173041  POLYGON ((-83.03596 42.34376, -83.03452 42.344...
# 189143  POLYGON ((-83.06831 42.43701, -83.06831 42.437...
# 201451  POLYGON ((-83.05331 42.43447, -83.05281 42.434...
# 201452  POLYGON ((-83.05331 42.43438, -83.05331 42.434...
# 201453  POLYGON ((-83.05330 42.43428, -83.05281 42.434...
# 238809  POLYGON ((-83.12842 42.41279, -83.12801 42.412...
# 262357  POLYGON ((-82.97015 42.44344, -82.97002 42.443...
# 267748  POLYGON ((-82.97588 42.42263, -82.97576 42.422...
# 268085  POLYGON ((-82.97576 42.42263, -82.97565 42.422...
# 272544  POLYGON ((-82.97724 42.40996, -82.97711 42.410...
# 272653  POLYGON ((-82.97711 42.41000, -82.97701 42.410...
# 274486  POLYGON ((-82.97438 42.42264, -82.97425 42.422...
# 279377  POLYGON ((-82.94326 42.36377, -82.94286 42.363...
# 296159  POLYGON ((-82.94951 42.44885, -82.94946 42.448...
# 322166  POLYGON ((-83.11785 42.36396, -83.11774 42.364...
# 331948  POLYGON ((-83.09945 42.32100, -83.09900 42.321...
# 333505  POLYGON ((-83.10787 42.32823, -83.10777 42.328...
# 345948  POLYGON ((-83.08785 42.32447, -83.08729 42.324...
# 357115  POLYGON ((-83.15310 42.32803, -83.15269 42.328...
# 361369  POLYGON ((-83.09438 42.31487, -83.09443 42.314...
#
# [43 rows x 41 columns]

# %%
len(parcel_gdf_nona)
# Out:
# 381183

# %% [markdown]
# - alright, 18224 HARTWELL should've been 18224 STOEPEL - alternate goal is to document any mistakes I find in the geocoding / data entry, and give that to the city. Needs to be added to the db
